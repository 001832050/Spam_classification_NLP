# %%
import nltk
nltk.download('wordnet')
import pandas as pd
# Out:
# [nltk_data] Downloading package wordnet to /Users/haozhou/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#nltk.download_shell()

# %% [markdown]
# ### import the data

# %%
mails = [line.rstrip() for line in open('smsspamcollection/SMSSpamCollection')]

# %%
mails[1]
# Out:
# 'ham\tOk lar... Joking wif u oni...'

# %% [markdown]
# ### Let's take a look at some mails:

# %%
for mail_no, mail in enumerate(mails[:9]):
    print(mail_no, mail)
    print('\n')
# Out:
# 0 ham	Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
#
#
# 1 ham	Ok lar... Joking wif u oni...
#
#
# 2 spam	Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
#
#
# 3 ham	U dun say so early hor... U c already then say...
#
#
# 4 ham	Nah I don't think he goes to usf, he lives around here though
#
#
# 5 spam	FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, £1.50 to rcv
#
#
# 6 ham	Even my brother is not like to speak with me. They treat me like aids patent.
#
#
# 7 ham	As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune
#
#
# 8 spam	WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.

# %% [markdown]
#  The data in our database has been separated by the category and the content, we will process the data later.

# %% [markdown]
# ### Now, we read in the data as a dataframe using pandas.

# %%
mails = pd.read_csv('smsspamcollection/SMSSpamCollection', sep='\t', names=['spam/ham', 'mail'])

# %%
mails.head(10)
# Out:
#   spam/ham                                               mail
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# 5     spam  FreeMsg Hey there darling it's been 3 week's n...
# 6      ham  Even my brother is not like to speak with me. ...
# 7      ham  As per your request 'Melle Melle (Oru Minnamin...
# 8     spam  WINNER!! As a valued network customer you have...
# 9     spam  Had your mobile 11 months or more? U R entitle...

# %%
import string

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ## Firstly, we need to create a base model.

# %% [markdown]
# The method here means that we need to at least remove the punctuations, and join them according to the whitespace between
# them, because if there's no mistakes in the sentence, we consider the words are seperated by white space.

# %%
def base_process(word):
    nonpunc = [char for char in word if char not in string.punctuation]
    nonpunc = ''.join(nonpunc)
    return nonpunc.split()

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
Bag_trans_base = CountVectorizer(analyzer=base_process).fit(mails['mail'])

# %%
print(Bag_trans_base.vocabulary_)
# Out:
# {'Go': 2113, 'until': 11060, 'jurong': 7805, 'point': 9192, 'crazy': 5985, 'Available': 1133, 'only': 8863, 'in': 7574, 'bugis': 5431, 'n': 8595, 'great': 7166, 'world': 11480, 'la': 7919, 'e': 6441, 'buffet': 5430, 'Cine': 1521, 'there': 10708, 'got': 7135, 'amore': 4853, 'wat': 11269, 'Ok': 3177, 'lar': 7952, 'Joking': 2535, 'wif': 11386, 'u': 10996, 'oni': 8858, 'Free': 1993, 'entry': 6556, '2': 423, 'a': 4651, 'wkly': 11439, 'comp': 5835, 'to': 10815, 'win': 11399, 'FA': 1882, 'Cup': 1589, 'final': 6783, 'tkts': 10808, '21st': 443, 'May': 2896, '2005': 430, 'Text': 4095, '87121': 871, 'receive': 9528, 'questionstd': 9434, 'txt': 10984, 'rateTCs': 9475, 'apply': 4934, '08452810075over18s': 73, 'U': 4221, 'dun': 6427, 'say': 9832, 'so': 10174, 'early': 6447, 'hor': 7427, 'c': 5476, 'already': 4828, 'then': 10703, 'Nah': 3047, 'I': 2362, 'dont': 6345, 'think': 10726, 'he':
578, 'help': 7324, 'granted': 7158, 'will': 11396, 'fulfil': 6979, 'wonderful': 11459, 'blessing': 5287, 'at': 5024, 'times': 10787, 'HAVE': 2175, 'A': 933, 'DATE': 1607, 'ON': 3146, 'SUNDAY': 3694, 'WITH': 4394, 'WILL': 4389, 'XXXMobileMovieClub': 4555, 'use': 11094, 'credit': 5990, 'click': 5756, 'WAP': 4359, 'link': 8069, 'next': 8679, 'message': 8388, 'httpwap': 7466, 'xxxmobilemovieclubcomnQJKGIGHJJGCBL': 11590, 'Oh': 3172, 'kim': 7869, 'watching': 11274, 'Eh': 1818, 'remember': 9595, 'how': 7448, 'spell': 10267, 'his': 7373, 'name': 8607, 'Yes': 4613, 'did': 6230, 'He': 2261, 'v': 1 ...

# %%
mails_bag_base = Bag_trans_base.transform(mails['mail'])

# %%
print('Shape:', mails_bag_base.shape)
# Out:
# Shape: (5572, 11747)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.cross_validation import train_test_split
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Then I split the data into train and test part, the first part is for train, and the second is
# to test the how the outcome of the train performs

# %%
mil_train, mil_test, label_train, label_test = train_test_split(mails['mail'], mails['spam/ham'], test_size = 0.5)

# %% [markdown]
# ## Scikit-learn Tf-IDF topic model

# %% [markdown]
# Now we use the tf-idf to calculate the importance of every word in the corpus

# %% [markdown]
# #### If we want to use the tf-idf model, we must use the dictionary of all words with their frequency occurs in the corpus.Just like we did before.

# %%
tfidf_transformer_base = TfidfTransformer().fit(mails_bag_base)

# %% [markdown]
# #### And now, tf-idf will count the importance of each word according to their frequency with its own equation, the bigger the frequency is doesn't mean it is important, because there are many useless words in the corpus but they are a lot like 'a', 'and', 'very' something like this.

# %%
mails_tfidf = tfidf_transformer_base.transform(mails_bag_base)

# %% [markdown]
#  We use pipeline to combine three models together.(Data preprocessing model, language model, topic model.)
# And we use classification report to test the value of the big model.

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=base_process)),
    ('tfidf', TfidfTransformer()),
    ('classifier', MultinomialNB())
])

pipeline.fit(mil_train, label_train)

pred = pipeline.predict(mil_test)

from sklearn.metrics import classification_report
print(classification_report(label_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#         ham       0.93      1.00      0.96      2411
#        spam       1.00      0.53      0.70       375
#
# avg / total       0.94      0.94      0.93      2786

# %% [markdown]
# ## Second, we want to add method to preprocess the text and then we can get how the methods affect the outcome.

# %% [markdown]
#  The two methods we use are stem and Lemmatization. The goal of these two methods are to remove the prefix and suffix of a word.

# %% [markdown]
# ### But the lemmatization is to return the word to its root, it's a more dictionary way to complete. If we want the word to return back to its root(lemmatization), we need to know its part of speech.
# ### And we need to define a method to get its part of speech.

# %%
from nltk.corpus import wordnet
from collections import Counter
def get_part_of_speech(word):
  probable_part_of_speech = wordnet.synsets(word)
  pos_counts = Counter()
  pos_counts["n"] = len(  [ item for item in probable_part_of_speech if item.pos()=="n"]  )
  pos_counts["v"] = len(  [ item for item in probable_part_of_speech if item.pos()=="v"]  )
  pos_counts["a"] = len(  [ item for item in probable_part_of_speech if item.pos()=="a"]  )
  pos_counts["r"] = len(  [ item for item in probable_part_of_speech if item.pos()=="r"]  )
  
  most_likely_part_of_speech = pos_counts.most_common(1)[0][0]
  return most_likely_part_of_speech

# %% [markdown]
# Stem follows an algorithm with steps to perform on the words which make it faster.

# %%
def text_process_stem(text):
    """
    1.tokenize
    2.stemmenize
    3.remove stopwords
    4.return cleaned text words
    """
    nonpunc = [char for char in text if char not in string.punctuation]
    nonpunc = ''.join(nonpunc)
    stemmer = PorterStemmer()
    stemmed = [stemmer.stem(token) for token in nonpunc.split()]
    stopword_remove = [word for word in stemmed if word.lower() not in stopwords.words('english')]
    return stopword_remove

# %%
def text_process_lemma(text):
    """
    1.tokenize
    2.lemmatizer
    3.remove stopwords
    4.return cleaned text words
    """
    nonpunc = [char for char in text if char not in string.punctuation]
    nonpunc = ''.join(nonpunc)
    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(token, get_part_of_speech(token)) for token in nonpunc.split()]
    stopword_remove = [word for word in lemmatized if word.lower() not in stopwords.words('english')]
    return stopword_remove

# %% [markdown]
# Both of the two methods remove the stop words, because they are useless to the corpus.

# %% [markdown]
# Now, lets extract some mails which use these two methods, and compare the difference.

# %%
mails['mail'].head(10).apply(text_process_stem)
# Out:
# 0    [Go, jurong, point, crazi, avail, onli, bugi, ...
# 1                         [Ok, lar, joke, wif, u, oni]
# 2    [free, entri, 2, wkli, comp, win, FA, cup, fin...
# 3        [U, dun, say, earli, hor, U, c, alreadi, say]
# 4    [nah, dont, think, goe, usf, live, around, tho...
# 5    [freemsg, hey, darl, 3, week, word, back, Id, ...
# 6    [even, brother, like, speak, treat, like, aid,...
# 7    [per, request, mell, mell, oru, minnaminungint...
# 8    [winner, valu, network, custom, select, receiv...
# 9    [mobil, 11, month, U, R, entitl, updat, latest...
# Name: mail, dtype: object

# %% [markdown]
# This is the output generated from the stem method.

# %%
mails['mail'].head(10).apply(text_process_lemma)
# Out:
# 0    [Go, jurong, point, crazy, Available, bugis, n...
# 1                       [Ok, lar, Joking, wif, u, oni]
# 2    [Free, entry, 2, wkly, comp, win, FA, Cup, fin...
# 3        [U, dun, say, early, hor, U, c, already, say]
# 4    [Nah, dont, think, go, usf, life, around, though]
# 5    [FreeMsg, Hey, darling, 3, week, word, back, I...
# 6    [Even, brother, like, speak, treat, like, aid,...
# 7    [per, request, Melle, Melle, Oru, Minnaminungi...
# 8    [WINNER, value, network, customer, select, rec...
# 9    [mobile, 11, month, U, R, entitle, Update, lat...
# Name: mail, dtype: object

# %% [markdown]
# This is the output generated from the lemmatization method.

# %% [markdown]
# We can find that the key difference between the word 'crazi' under stem process and 'crazy' under lemmatization process, 'alreadi' and 'already', 'darl' and 'darling', 'entitl' and 'entitle', 'updat' and 'Update', 'mobil' and 'mobile', which can see the lemmatization is more like a dictionary transform.

# %% [markdown]
# #### Now we will convert each messages into a vector the Scikit Learn's algorithm models can work with

# %% [markdown]
# #### Bag of words model:

# %% [markdown]
# 1. Count how many times does a word occur in each message.
# 2. Weight the counts, so that frequent tokens get lower weight.
# 3. Normalize the vectors to unit length, to abstract from the original text length.
#
# And this model will convert a collection of text documents to a matrix od token counts.
# And it will be surely for the scikit learn to output a sparse matrix

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
, 'Prize': 3278, 'Jackpot': 2416, 'Txt': 4057, 'CLAIM': 1373, '81010': 816, 'TC': 3842, 'wwwdbuknet': 10116, 'LCCLTD': 2546, 'POBOX': 3133, '4403LDNW1A7RW18': 622, 'search': 8770, 'right': 8632, 'thank': 9402, 'breather': 5064, 'promise': 8374, 'wont': 10041, 'take': 9323, 'help': 6658, 'grant': 6524, 'fulfil': 6372, 'wonderful': 10040, 'blessing': 4989, 'time': 9485, 'DATE': 1563, 'SUNDAY': 3562, 'XXXMobileMovieClub': 4365, 'use': 9746, 'credit': 5566, 'click': 5376, 'WAP': 4195, 'link': 7284, 'next': 7787, 'message': 7540, 'httpwap': 6773, 'xxxmobilemovieclubcomnQJKGIGHJJGCBL': 10158, 'Oh': 3054, 'kim': 7123, 'watch': 9892, 'Eh': 1764, 'remember': 8559, 'spell': 9078, 'name': 7725, 'Yes': 4420, 'v': 9765, 'naughty': 7742, 'make': 7430, 'wet': 9953, 'Fine': 1909, 'that\x92s': 9415, 'way': 9902, 'feel': 6190, 'That\x92s': 3959, 'gota': 6505, 'b': 4822, 'England': 1779, 'Macedonia': 2767, 'miss': 7590, 'goalsteam': 6474, 'news': 7782, 'ur': 9730, 'national': 7736, 'team': 9357, '87077': 865, 'eg': 5967, 'ENGLAND': 1723, 'TryWALES': 4037, 'SCOTLAND': 3455, '4txtú120': 673, 'POBOXox36504W45WQ': 3136, 'seriously': 8816, 'I‘m': 2396, 'try': 9624, 'ha': 6576, 'joke': 7048, 'ü': 10300, 'pay': 8099, 'first': 6237, 'da': 5614, 'stock': 9162, 'comin': 5436, 'Aft': 1014, 'finish': 6227, 'lunch': 7382, 'str': 9175, 'lor': 7332, 'Ard': 1079, 'smth': 8984, 'Ffffffffff': 1900, 'Alright': 1048, 'meet': 7505, 'sooner': 9032, 'force': 6292, 'eat': 5947, 'slice': 8952, 'really': 8490, 'hungry': 6795, 'tho': 9450, 'suck': 9227, 'Mark': 2789, 'worry': 10061, 'know': 7141, 'sick': 8894, 'turn': 9 ...

# %%
for key in Bag_trans.vocabulary_:
    print(key)
# Out:
# Go
# jurong
# point
# crazy
# Available
# bugis
# n
# great
# world
# la
# e
# buffet
# Cine
# get
# amore
# wat
# Ok
# lar
# Joking
# wif
# u
# oni
# Free
# entry
# 2
# wkly
# comp
# win
# FA
# Cup
# final
# tkts
# 21st
# May
# 2005
# Text
# 87121
# receive
# questionstd
# txt
# rateTCs
# apply
# 08452810075over18s
# U
# dun
# say
# early
# hor
# c
# already
# Nah
# dont
# think
# go
# usf
# life
# around
# though
# FreeMsg
# Hey
# darling
# 3
# week
# word
# back
# Id
# like
# fun
# still
# Tb
# ok
# XxX
# std
# chgs
# send
# £150
# rcv
# Even
# brother
# speak
# treat
# aid
# patent
# per
# request
# Melle
# Oru
# Minnaminunginte
# Nurungu
# Vettam
# set
# callertune
# Callers
# Press
# 9
# copy
# friend
# Callertune
# WINNER
# value
# network
# customer
# select
# receivea
# £900
# prize
# reward
# claim
# call
# 09061701461
# dao
# half8th
# Exactly
# jide
# Dunno
# Email
# AlertFrom
# Jeri
# StewartSize
# 2KBSubject
# Lowcost
# prescripiton
# drvgsTo
# Spring
# yay
# steak
# convincingjust
# tel
# twice
# neglect
# itjust
# Leaving
# tonite
# opportunityall
# fastpls
# add
# prayer
# dearRakhesh
# Loyalty
# OfferThe
# NEW
# Nokia6650
# £10
# TXTAUCTION
# START
# 81151
# 4TCtxt
# 150pMTmsg
# Wish
# mayb
# rite
# Da
# gd
# gal
# attach
# Glad
# Thing
# hadnt
# clock
# shout
# realise
# wahay
# Men
# Gaze
# eye
# 930
# subscribe
# Content
# £3
# 82324
# Helpline
# 08706091795
# weve
# Give
# gist
# 40
# thousand
# tattoo
# PREMIER
# gimme
# lip
# caveboy
# library
# Realy
# sorryi
# confuse
# holla
# anyone
# spare
# Faith
# possibleHope
# workLove
# beautifulMay
# ChristmasMerry
# youcarlos
# isare
# vibrate
# act
# Romantic
# Paris
# £79
# 08704439680TsCs
# grandma
# hungover
# Another
# unclaimed
# 09066368327
# closingdate040902
# claimcode
# M39M51
# £150pmmorefrommobile2BremovedMobyPOBox734LS27YF
# gua
# mt
# faber
# yest
# Yest
# Jus
# Wishing
# Year
# advance
# City
# Break
# Summer
# Shopping
# WK
# STORE
# 88039
# SkilGme
# TsCs087147403231WinawkAge16
# £150perWKsub
# nt
# goin
# meetin
# wonder
# ti
# Theyre
# dramatic
# Schools
# Apparently
# anywhere
# damn
# hunt
# drunkard
# Wats
# idc
# weaseling
# row
# space
# trash
# beg
# lovely
# sing
# slave
# punish
# Beerage
# 0578
# randomlly
# opening
# couldnt
# shes
# diff
# Ever
# perfect
# community
# 100pSMS
# Top
# Polyphonic
# 087018728737
# National
# Rate
# toppoly
# tune
# SUBPOLY
# 81618
# pole
# UnSub
# 08718727870
# fondly
# bein
# thot
# YWHERE
# DOGBREATH
# SOUNDING
# JAN
# THATS
# AL
# Omg
# weigh
# Woohoo
# uncountable
# dictionary
# piece
# 9996
# 14thMarch
# availa
# Petey
# whereare
# friendsare
# theKingshead
# canlove
# Nic
# Gimme
# ago
# Chance
# POBOX84
# M263UZ
# Appt
# ltTIMEgt
# No1
# 8077
# mate
# wwwgetzedcouk
# POBox
# 36504
# W45WQ
# norm150ptone
# cashto
# 08000407165
# getstop
# 88222
# PHP
# RG21
# 4JX
# dled
# 3d
# imp
# aint
# smokin
# Boooo
# bec
# Ugh
# Ssnervous
# costume
# gift
# yowifes
# Hint
# hint
# £100
# borrow
# bag
# outbid
# simonwatson5120
# Shinco
# Plyr
# bid
# acsmsrewards
# notification
# model
# Youi
# Also
# galileo
# dobby
# BOO
# ENJOYIN
# YOURJOB
# SEEMED
# GETTIN
# HUNNYHOPE
# OKTAKE
# ILLSPEAK
# 2U
# SOONLOTS
# LOVEME
# XXXX
# starshine
# Ache
# fuck
# sip
# cappuccino
# tease
# SMSSERVICES
# yourinclusive
# goto
# wwwcomuknet
# 3qxj9
# extra
# 08702840625COMUK
# 220CM2
# 9AE
# Nyt
# 3lp
# £150msg
# response
# alsoor
# danalla
# obedient
# ft
# combination
# needy
# pout
# stomp
# northampton
# abj
# serve
# playng
# 1McFlyAll
# Ab
# Sara
# JorgeShock
# SmithSwitch
# anna
# nagar
# Chasing
# Yupz
# modelsony
# ericson
# der
# luks
# modl
# cheesy
# frosty
# witin
# PLUS
# SPORT
# 0870141701216
# 4txt120p
# Europe
# 10th
# Sept
# 09050000555
# BA128NNFWFLY150ppm
# nudist
# theme
# YM
# pump
# petrol
# £12
# Feb
# VALUED
# FRNDS
# evn
# ignore
# Evr
# signal
# neither
# unusual
# Hugs
# snog
# Omw
# west
# palm
# printing
# optout
# 83021
# state
# Reaction
# DOUBLE
# tariff
# 2stoptxt
# perpetual
# DD
# steam
# reg
# pract
# Flung
# HouseMaid
# public
# govtinstituitions
# closedincluding
# officeunderstand
# ...
# fishrman
# ful
# strtd
# throwin
# Atlast
# 1stone
# MoralDont
# 08717895698
# MobStoreQuiz10ppm
# physic
# ArPraveesh
# delicious
# transaction
# Salad
# desert
# WHORE
# UNBELIEVABLE
# funk
# TONES2U
# Twinks
# bear
# scallies
# skin
# jock
# 08712466669
# 08712460324nat
# flood
# dr
# bead
# wishlist
# section
# nitro
# History
# Comfort
# Luxury
# Sold
# OnionRs
# PetrolRs
# BeerRs
# nvm
# armands
# creative
# fakemy
# reffering
# uif
# getiing
# rsi
# weirdy
# 09061701851
# K61
# 12hours
# restrict
# funeral
# Audrey
# godnot
# chikkuk
# vivek
# 74355
# iscoming
# TnC
# brah
# possession
# outif
# greece
# protect
# ethreats
# SIB
# sensitive
# PasswordsATMSMS
# PIN
# someday
# Goodmorningmy
# grandfather
# expiredso
# Blu
# concert
# November
# 09061104276
# TSCs
# cost£375max
# yuou
# pc
# spot
# ipad
# bunch
# lotto
# Deal
# Early
# authorise
# 645pm
# Thatll
# HOWS
# HONEYDID
# HOLIDAY
# GIMMI
# DE
# GOSSx
# painit
# todaydo
# ystrdayice
# chile
# sublet
# febapril
# ammaelife
# steering
# anythings
# rounderso
# truekDo
# lambu
# ji
# cometil
# batchlor
# zoom
# nowSend
# 62220Cncl
# STOPCS
# 08717890890£150
# cheese
# Harry
# pink
# RingtoneFrom
# httptms
# widelivecomindex
# wmlid1b6a5ecef91ff937819firsttrue180430JUL05
# xafter
# cst
# chg
# pure
# hearted
# hisher
# SMILEY
# GAIL
# NEVA
# WRONGTAKE
# SWEET
# WORRYC
# L8TR
# HUNLOVE
# Yaxxx
# Theoretically
# therere
# formallyPls
# prayingwill
# multimedia
# senthilhsbc
# vague
# accounting
# housing
# agency
# Loads
# nicky
# Gumbys
# httpalto18coukwavewaveaspo44345
# tarpon
# Cab
# availablethey
# step
# oktake
# careumma
# Unlimited
# Limited
# call2optoutHF8
# YESTERDAY
# 09061702893
# 07XXXXXXXXX
# 08719181259
# 260305
# handset
# Line
# deartake
# radiator
# Serious
# proper
# tongue
# qi
# suddenly
# flurry
# melt
# grind
# Eek
# FREERingtone
# REAL1
# PushButton
# POBox84
# Exorcism
# Emily
# gooD
# Evry
# Emotion
# dsnt
# WordsEvry
# Prayrs
# SmileD
# uOthrwise
# Stay
# uSo
# Ujhhhhhhh
# sandiago
# parantella
# Wtf
# Poop
# sweater
# mango
# massive
# del
# £600
# Complete
# landmark
# Big
# Bob
# Barry
# Ben
# 83738
# fineabsolutly
# consent
# form
# TONEXS
# wwwclubzedcouk
# BILLING
# wwwtcbiz
# Polo
# Suite
# 373
# W1J
# 6HL
# can‘t
# Mathews
# tait
# anderson
# haunt
# promote
# Joke
# crowd
# cardiff
# 8000930705
# snowboarding
# goa
# Sim
# christmassy
# RECPT
# 13
# Baaaaaaaabe
# Shola
# academic
# Sagamu
# lautech
# vital
# education
# Nigeria
# zealand
# qet
# FRIENDS
# CLoSE
# UNDERSTaND
# TRUE
# STaY
# dial
# browser
# GB
# wellyou
# lifeyou
# CONVINCED
# thati
# conversation
# usGET
# timeYour
# sensesrespect
# overemphasiseor
# Headset
# ADP
# internal
# extract
# godYou
# immed
# skint
# bevieswaz
# othrs
# spoon
# watchng
# planet
# earthsofa
# comfey
# least5times
# wudnt
# coast
# Üll
# MMM
# Ima
# frequently
# messageit
# cupboard
# route
# 2mro
# yellow
# floppy
# snappy
# grasp
# flavour
# laready
# deny
# Dom
# TAMPA
# FFFFUUUUUUU
# annie
# julianaland
# oblivious
# upsetits
# dehydrate
# mapquest
# dogwood
# tiny
# parking
# archive
# UKmobiledate
# 08719839835
# Future
# mg
# 89123
# behalf
# stun
# visa
# gucci
# CALLIN
# BABESOZI
# CULDNT
# TALKBUT
# WANNATELL
# DETAILS
# LATER
# WENWECAN
# PROPERLY
# smsing
# efficient
# explicit
# 30
# Ring
# 02073162414
# Costs
# 20pmin
# 515pm
# Erutupalam
# thandiyachu
# invention
# flyim
# Noits
# lyric
# reckon
# nevr
# unrecognized
# somone
# definitly
# undrstnd
# ger
# toking
# syd
# lehHaha
# khelate
# kintu
# opponenter
# dhorte
# lage
# spar
# looovvve
# warwick
# tmw
# havnt
# sometime
# parade
# iPOD
# proze
# Norcorp
# Ltd£150Mtmsgrcvd18
# chennaibecause
# 7cfca1a
# grumble
# linear
# algebra
# decorate
# 946
# roomate
# graduate
# adjustable
# cooperative
# Nottingham
# 63miles
# 40mph
# clearly
# Thanku
# 2MORRO
# 89938
# string
# £150ea
# OTBox
# 731
# LA1
# 7WS
# Understand
# School
# MISSED
# HAVENT
# BORED
# SAD
# ISNT
# ITxx
# beside
# brisk
# 89070
# steve
# TELLMISS
# Normally
# Dare
# Partys
# contribute
# greatly
# Urgh
# coach
# duvet
# predictive
# Ready
# chatIm
# w8in
# 4uTxt
# url
# Deliver
# 24th
# sept
# cha
# lil
# beverage
# vpist
# surrender
# SYMPTOMS
# 1U
# 3U
# Gettin
# rdy
# PISS
# TALKING
# REALISE
# POINT
# ITNOW
# READ
# BACKWARDS
# police
# abstract
# vikkyim
# hiya
# africa
# avin
# CHITCHAT
# Logon
# 8883
# CM
# 4217
# W1A
# 6ZF
# camry
# olayiwolas
# Mileage
# kit
# Holla
# clover
# numberpls
# idconvey
# achanammaRakheshQatar
# rencontre
# Mountains
# 08714712412
# galsU
# nìte
# puppy
# noise
# sarasota
# 150pmeg
# HGSuite3422lands
# RowW1j6HL
# 08715203685
# Code4xx26
# 131004
# 09094646631
# nat
# inconvenient
# vldo
# adsense
# dudette
# perumbavoor
# stage
# cherish
# clarify
# preponed
# Natalie
# 20F
# YES165
# NO165
# wwwSMSacunatalie2k9
# young
# Jamster
# wallpaper
# 08701213186
# liver
# stylish
# Hmmmstill
# opener
# loneliness
# skyving
# Pilates
# Afternoon
# onwords
# mtnl
# mumbai
# 83039
# 62735£450
# AccommodationVouchers
# mustprovide
# 15541
# Rajitha
# Ranju
# 5p
# Starting
# TsCs08714740323
# 1Winawk
# £150perweeksub
# dearslp
# welltake
# careswt
# dreamsMuah
# 09066361921
# disagreeable
# Guy
# afterwards
# battle
# VIVEKANAND
# SD
# UAWAKEFEELLIKW
# SHITJUSTFOUND
# VIA
# ALETTER
# THATMUM
# GOTMARRIED
# 4thNOVBEHIND
# OURBACKS
# FUCKINNICESELFISHDEVIOUSBITCHANYWAYIL
# rearrange
# Dormitory
# Dirty
# Astronomer
# Moon
# starer
# Election
# Lies
# recount
# Motherinlaw
# Woman
# Hitler
# Eleven
# Twelve
# worm
# dysentry
# andre
# virgil
# lorgoin
# Gokila
# ShanilRakhesh
# herethanksi
# exchange
# uncut
# stuffleaving
# Dino
# Prem
# Kkthis
# kotees
# TheMobHit
# Pink
# Panther
# Sugababes
# Zebra
# badass
# Hoody
# wallpaperall
# resent
# Queries
# customersqueriesnetvisionukcom
# hassle
# andres
# HAUGHAIGHGTUJHYGUJ
# Ding
# fassyole
# Blacko
# londn
# KISS
# 4EVA
# 08715205273
# VCo
# humanity
# Fills
# calm
# reassurance
# Aslamalaikkuminsha
# tohar
# beeen
# muht
# albi
# mufti
# mahfuuzmeaning
# 078
# ENUFCREDEIT
# TOCALLSHALL
# ILEAVE
# UNI
# Chikku
# Okors
# ibored
# zero
# goigng
# perfume
# Sday
# joinedso
# grocer
# Frankie
# Bennys
# warner
# diaper
# Unlike
# patient
# turkey
# dawhere
# unintentionally
# garden
# bulb
# seed
# £3350
# Scotsman
# go2
# notxtcouk
# wenever
# familymay
# stability
# tranquility
# vibrant
# colourful
# bawl
# failure
# YEARS
# BOYFRIEND
# SI
# Velusamy
# facility
# karnan
# bluray
# I‘ve
# salt
# wound
# Water
# Geoenvironmental
# implication
# gently
# Sms
# Fuuuuck
# salmon
# WRKIN
# ree
# compensation
# awkward
# i‘m
# splash
# Musta
# overdo
# wwwtelediscountcouk
# STUDENT
# DISCOUNT
# BOOKS
# 2StopTxt
# Hiwhat
# gastroenteritis
# reduce
# illness
# Jane
# wrk
# lst
# Foned
# chuck
# nightsWe
# port
# liaoToo
# JUSWOKE
# BOATIN
# DOCKS
# SLEPT
# WID
# OLD
# SPINOUT
# GIV
# GOSSIP
# remet
# nichols
# 08715203656
# 42049
# 261004
# Started
# uworld
# qbank
# assessment
# Someonone
# 09064015307
# BOX334SK38ch
# tke
# temales
# vidnot
# finishd
# 09061213237
# 177
# M227XY
# dull
# anyones
# treadmill
# Craigslist
# absolutely
# South
# Park
# drmstake
# SOMETHIN
# CALLED
# SWAN
# PARENTS
# ER
# INDIANS
# MOyeP
# SaLL
# gOoD
# HehE
# shexy
# Xx
# teethif
# asapok
# HelloHow
# doingWhat
# 2When
# lamp
# latebut
# kwish
# foward
# 09061790126
# Vikky
# misundrstud
# 2u2
# gene
# wwwLdewcom1win150ppmx3age16subscription
# minimum
# reapply
# london
# treatin
# treacle
# mumHas
# beendropping
# theplace
# adress
# Jolly
# moneyi
# favorite
# oyster
# sashimi
# rumble
# Kothi
# marandratha
# topic
# correctly
# SirSalam
# AlaikkumPride
# Tea
# ShopWe
# QatarRakhesh
# IndianPls
# NumberRespectful
# Regards
# Gal
# galcan
# boyy
# galno
# heaven
# princeGN
# pisces
# aquarius
# 2yrs
# steyn
# wicket
# Neither
# sterm
# resolve
# Garbage
# jam
# hannaford
# wheat
# chex
# pride
# grownup
# stuffwhy
# Jerk
# stink
# TEXTCOMP
# subsequent
# charged150pmsg2
# 84128custcare
# upcharge
# 8hr
# Guai
# bottle
# amuse
# astrology
# ryans
# slack
# officestill
# formsdon
# mentor
# percent
# 09095350301
# erotic
# ecstacy
# dept
# 13404
# 08717507382
# datingi
# coincidence
# sane
# 151
# pause
# gr8prizes
# 8800
# PSP
# wkTXT
# httpwwwgr8prizescom
# spacebucks
# 02070836089
# squeeze
# tooPray
# meRemove
# maintain
# 5Im
# dread
# thou
# suggestion
# Lands
# forgt
# Soon
# FIGHTS
# ajith
# Ooooooh
# yoville
# mega
# asda
# officer
# respectful
# bffs
# carly
# HARD
# express
# someonethat
# seperated鈥┾〨ud
# Babes
# brolly
# English
# Franxx
# welli
# prometazine
# syrup
# 5mls
# shu
# singapore
# victoria
# traffic
# whens
# pocay
# wocay
# 4eva
# 2morrowxxxx
# East
# broth
# ramen
# fowler
# ksry
# sivatats
# Calling
# 09058094583
# 1526
# pubcafe
# attention
# tix
# Mode
# biolas
# fne
# youdoing
# Sar
# worc
# foregate
# shrub
# get4an18th
# 32000
# legitimat
# efreefone
# shopthe
# pendent
# toilet
# HU
# navigate
# guidance
# Except
# chick
# boob
# sparkle
# 45
# 0121
# 2025050
# wwwshortbreaksorguk
# Gyno
# wwwgambtv
# treasure
# wmlid820554ad0a1705572711firsttrue¡C
# Ringtone¡
# 09050000332
# positive
# negative
# Hmmmm
# Dhoni
# titleso
# command
# stressful
# Holby
# 09064017295
# li
# lecturer
# yeovil
# motor
# max
# rhode
# bong
# Ofcourse
# 2p
# 08448350055
# PlanetTalkInstantcom
# loti
# Marvel
# Ultimate
# Spiderman
# SPIDER
# 83338
# 8Ball
# tamilnaduthen
# 07808247860
# 08719899229
# 40411
# 061104
# Apo
# Perhaps
# identification
# boundary
# endless
# Machan
# reassure
# lorWe
# referin
# liaoSo
# Miles
# saibaba
# colany
# chic
# Common
# Declare
# 49557
# 261104
# disappointment
# irritation
# tantrum
# Compliments
# chief
# Gsex
# 2667
# WC1N
# 3XX
# 3MOBILE
# CHATLINES
# INCLU
# MINS
# CUST
# SERVs
# SED
# L8ER
# MEGA
# BILL
# BAILIFF
# DUE
# Armand
# mouse
# desk
# Ic
# childporn
# jumper
# hat
# belt
# Cribbs
# spiritual
# sudden
# influx
# Yeh
# Tho
# kane
# shud
# Mite
# Pshewmissing
# unit
# accent
# 4years
# dental
# nmde
# dump
# heap
# BORING
# salesman
# REMINDER
# £750
# 087187272008
# NOW1
# Pity
# Soany

# %% [markdown]
# The corpus becomes a dictionary of the words' appearance and its frequency in the corpus.

# %%
print(len(Bag_trans.vocabulary_))
# Out:
# 10307

# %%
mess1 = mails['mail'][2]
print(mess1)
# Out:
# Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's

# %% [markdown]
# #### This is give an example of one mail and count the words frequency and frequency of that words in the whole mails overall.

# %%
bow1 = Bag_trans.transform([mess1])
print(bow1)
# Out:
#   (0, 73)	1
#   (0, 420)	1
#   (0, 427)	1
#   (0, 440)	1
#   (0, 866)	1
#   (0, 1546)	1
#   (0, 1828)	2
#   (0, 1936)	1
#   (0, 2799)	1
#   (0, 3948)	1
#   (0, 4702)	1
#   (0, 5445)	1
#   (0, 6029)	2
#   (0, 6216)	1
#   (0, 8429)	1
#   (0, 8464)	1
#   (0, 8505)	1
#   (0, 9504)	1
#   (0, 9649)	1
#   (0, 9994)	1
#   (0, 10024)	1

# %% [markdown]
# The shape of this vector, which means that this is one column in a matrix, because we only choose only one mail to check.

# %%
print(bow1.shape)
# Out:
# (1, 10307)

# %% [markdown]
# We can easily according to the frequency the word occurs in the corpus to get the word like the 'entry'

# %%
Bag_trans.get_feature_names()[6029]
# Out:
# 'entry'

# %%
mess0 = mails['mail'][5570]
print(mess0)
# Out:
# The guy did some bitching but I acted like i'd be interested in buying something else next week and he gave it to us for free

# %%
bow0 = Bag_trans.transform([mess0])
print(bow0)
# Out:
#   (0, 4501)	1
#   (0, 4973)	1
#   (0, 5131)	1
#   (0, 5989)	1
#   (0, 6326)	1
#   (0, 6458)	1
#   (0, 6569)	1
#   (0, 6829)	1
#   (0, 6926)	1
#   (0, 7272)	1
#   (0, 7787)	1
#   (0, 9016)	1
#   (0, 9659)	1
#   (0, 9925)	1

# %% [markdown]
# I can check the appearance of the words in any single sentence. And the others are 0,
# means they don't have those words in the sentence.

# %%
print(bow0.shape)
# Out:
# (1, 10307)

# %% [markdown]
# #### Lets look at the shape of the matrix:

# %%
mails_bag = Bag_trans.transform(mails['mail'])
print('Shape:', mails_bag.shape)
# Out:
# Shape: (5572, 10307)

# %% [markdown]
# The shape of the matrix, which means give me the all words appear in all the mails.

# %% [markdown]
# #### Scikit-learn Tf-IDF topic model

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_transformer = TfidfTransformer().fit(mails_bag)

# %%
tfidf_transformer.idf_[Bag_trans.vocabulary_['U']]
# Out:
# 3.966206571809915

# %% [markdown]
#  This is the importance of the letter "U"

# %%
mails_tfidf = tfidf_transformer.transform(mails_bag)

# %%
print(mails_tfidf)
# Out:
#   (0, 10056)	0.22851328683149133
#   (0, 9891)	0.19320182292856627
#   (0, 8222)	0.2206047642981321
#   (0, 7713)	0.17267405357648447
#   (0, 7167)	0.26744965756318645
#   (0, 7070)	0.316581887144617
#   (0, 6532)	0.18584279065768133
#   (0, 6437)	0.11694033219453179
#   (0, 5936)	0.19160269099296262
#   (0, 5561)	0.25307940162220666
#   (0, 5108)	0.2721821986617856
#   (0, 5107)	0.3022116312036372
#   (0, 4629)	0.316581887144617
#   (0, 2055)	0.2451708790888474
#   (0, 1478)	0.316581887144617
#   (0, 1105)	0.29201577235390175
#   (1, 9984)	0.40103983782285263
#   (1, 9659)	0.20138826796353052
#   (1, 7946)	0.5048746566867236
#   (1, 7196)	0.3771390523485955
#   (1, 3059)	0.2915079040425609
#   (1, 2446)	0.5625839245085561
#   (2, 10024)	0.19189047507643978
#   (2, 9994)	0.13698686353239958
#   (2, 9649)	0.14057561470333804
#   :	:
#   (5568, 6469)	0.24367405620663118
#   (5568, 6320)	0.48803929715486144
#   (5568, 6051)	0.569508095387208
#   (5568, 4822)	0.39356061779270535
#   (5569, 9238)	0.5029225278766244
#   (5569, 7639)	0.4381269476511542
#   (5569, 3716)	0.5268366486379191
#   (5569, 3223)	0.5268366486379191
#   (5570, 9925)	0.22279906167120478
#   (5570, 9659)	0.146994533953008
#   (5570, 9016)	0.2527713312418127
#   (5570, 7787)	0.2558371675108212
#   (5570, 7272)	0.1931100891948576
#   (5570, 6926)	0.31800735003154385
#   (5570, 6829)	0.3025395508700758
#   (5570, 6569)	0.25351883562324756
#   (5570, 6458)	0.2255860062462255
#   (5570, 6326)	0.22683415096724188
#   (5570, 5989)	0.29452443734226
#   (5570, 5131)	0.24852488292259214
#   (5570, 4973)	0.35304331429519686
#   (5570, 4501)	0.36012969913370596
#   (5571, 9618)	0.5413811310320402
#   (5571, 7725)	0.479058339221186
#   (5571, 3426)	0.6909483183170129

# %% [markdown]
# This is output shows me the whole matrix with every words and its frequency occurs in corpus.

# %% [markdown]
# ### Naive Bayes Alogorithm

# %%
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# #### We use the matrix consists of the importance of each word and their labels to fit in the algorithm of Naive Bayes.

# %%
spam_detect_model = MultinomialNB().fit(mails_tfidf, mails['spam/ham'])

# %%
all_pred = spam_detect_model.predict(mails_tfidf)

# %% [markdown]
# #### Let's check the outcome.

# %%
all_pred
# Out:
# array(['ham', 'ham', 'spam', ..., 'ham', 'ham', 'ham'], dtype='<U4')

# %%
from sklearn.cross_validation import train_test_split

# %%
mil_train, mil_test, label_train, label_test = train_test_split(mails['mail'], mails['spam/ham'], test_size = 0.3)

# %% [markdown]
# ### Naive Bayes Algorithm

# %% [markdown]
# ### Lemmatization

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=text_process_lemma)),
    ('tfidf', TfidfTransformer()),
    ('classifier', MultinomialNB())
])

pipeline.fit(mil_train, label_train)

pred = pipeline.predict(mil_test)

from sklearn.metrics import classification_report
print(classification_report(label_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#         ham       0.96      1.00      0.98      1476
#        spam       1.00      0.71      0.83       196
#
# avg / total       0.97      0.97      0.96      1672

# %% [markdown]
# ### Stem

# %%
pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=text_process_stem)),
    ('tfidf', TfidfTransformer()),
    ('classifier', MultinomialNB())
])

pipeline.fit(mil_train, label_train)

pred = pipeline.predict(mil_test)

print(classification_report(label_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#         ham       0.97      1.00      0.98      1476
#        spam       0.99      0.73      0.84       196
#
# avg / total       0.97      0.97      0.97      1672

# %% [markdown]
# ### GBM Algorithm

# %% [markdown]
# ### Base model

# %%
from sklearn.ensemble import GradientBoostingClassifier

pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=base_process)),
    ('tfidf', TfidfTransformer()),
    ('classifier', GradientBoostingClassifier())
])

pipeline.fit(mil_train, label_train)

pred = pipeline.predict(mil_test)

print(classification_report(label_test, pred))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#              precision    recall  f1-score   support
#
#         ham       0.96      1.00      0.98      1476
#        spam       1.00      0.70      0.82       196
#
# avg / total       0.97      0.96      0.96      1672

# %% [markdown]
# ### Lemmatization

# %%
pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=text_process_lemma)),
    ('tfidf', TfidfTransformer()),
    ('classifier', GradientBoostingClassifier())
])

pipeline.fit(mil_train, label_train)

pred = pipeline.predict(mil_test)

print(classification_report(label_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#         ham       0.96      1.00      0.98      1476
#        spam       0.96      0.67      0.79       196
#
# avg / total       0.96      0.96      0.95      1672

# %% [markdown]
# ### Stem

# %%
pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=text_process_stem)),
    ('tfidf', TfidfTransformer()),
    ('classifier', GradientBoostingClassifier())
])

pipeline.fit(mil_train, label_train)

pred = pipeline.predict(mil_test)

print(classification_report(label_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#         ham       0.96      0.99      0.98      1476
#        spam       0.93      0.72      0.81       196
#
# avg / total       0.96      0.96      0.96      1672

# %% [markdown]
# ### Randomforest Algorithm

# %% [markdown]
# ### Base model

# %%
from sklearn.ensemble import RandomForestClassifier

pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=base_process)),
    ('tfidf', TfidfTransformer()),
    ('classifier', RandomForestClassifier())
])

pipeline.fit(mil_train, label_train)

pred = pipeline.predict(mil_test)

print(classification_report(label_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#         ham       0.96      1.00      0.98      1476
#        spam       0.99      0.70      0.82       196
#
# avg / total       0.96      0.96      0.96      1672

# %% [markdown]
# ### Lemmatization

# %%
pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=text_process_lemma)),
    ('tfidf', TfidfTransformer()),
    ('classifier', RandomForestClassifier())
])

pipeline.fit(mil_train, label_train)

pred = pipeline.predict(mil_test)

print(classification_report(label_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#         ham       0.97      1.00      0.98      1476
#        spam       1.00      0.75      0.86       196
#
# avg / total       0.97      0.97      0.97      1672

# %% [markdown]
# ### Stem

# %%
pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=text_process_stem)),
    ('tfidf', TfidfTransformer()),
    ('classifier', RandomForestClassifier())
])

pipeline.fit(mil_train, label_train)

pred = pipeline.predict(mil_test)

print(classification_report(label_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#         ham       0.97      1.00      0.98      1476
#        spam       0.96      0.76      0.85       196
#
# avg / total       0.97      0.97      0.97      1672

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# ### Base model

# %%
from sklearn.linear_model import LogisticRegression
pipeline = Pipeline([
    ('baw', CountVectorizer(analyzer=base_process)),  
    ('tfidf', TfidfTransformer()),  
    ('model', LogisticRegression()), 
])
pipeline.fit(mil_train, label_train)
pred = pipeline.predict(mil_test)
#Evaluation
print (classification_report(label_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#         ham       0.96      1.00      0.98      1476
#        spam       0.99      0.69      0.82       196
#
# avg / total       0.96      0.96      0.96      1672

# %% [markdown]
# ### Lemmatization

# %%
pipeline = Pipeline([
    ('baw', CountVectorizer(analyzer=text_process_lemma)),  
    ('tfidf', TfidfTransformer()),  
    ('model', LogisticRegression()), 
])
pipeline.fit(mil_train, label_train)
pred = pipeline.predict(mil_test)
#Evaluation
print (classification_report(label_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#         ham       0.95      1.00      0.98      1476
#        spam       0.98      0.64      0.77       196
#
# avg / total       0.96      0.96      0.95      1672

# %% [markdown]
# ### Stem

# %%
pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=text_process_stem)),
    ('tfidf', TfidfTransformer()),
    ('classifier', RandomForestClassifier())
])

pipeline.fit(mil_train, label_train)

pred = pipeline.predict(mil_test)

print(classification_report(label_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#         ham       0.97      1.00      0.98      1476
#        spam       0.98      0.74      0.84       196
#
# avg / total       0.97      0.97      0.97      1672
